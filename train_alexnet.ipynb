# %%
from google.colab import drive
drive.mount('/content/drive')
ROOT = '/content/drive'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/week2/project/alexnet
# !ls
# Out:
# /content/drive/MyDrive/ColabNotebooks/week2/project/alexnet
# base	     exe.ipynb	parse_config.py   saved		       trainer	 wandb
# config.json  logger	__pycache__	  test.py	       train.py
# data_loader  model	requirements.txt  train_alexnet.ipynb  utils

# %%
# !ls /content/drive/MyDrive/ColabNotebooks/week2/project/alexnet/data/cervical/labeled_1-1000/

# %%
# !rm /content/drive/MyDrive/ColabNotebooks/week2/project/alexnet/data/cervical/labeled_1-1000/right.zip

# %% [markdown]
# ## install wandb

# %%
# !pip install wandb -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 26.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 20.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 20.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 7.4 MB/s eta 0:00:00
# ...

# %%
import wandb
wandb.init(project='classification_mnist', entity = 'nebulajo98')
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.13.11
# Run data is saved locally in <code>/content/drive/MyDrive/ColabNotebooks/week2/project/pytorch-template/alexnet/wandb/run-20230314_152133-ut1w7zmn</code>
# Syncing run <strong><a href='https://wandb.ai/nebulajo98/classification_mnist/runs/ut1w7zmn' target="_blank">mocha-brownie-1</a></strong> to <a href='https://wandb.ai/nebulajo98/classification_mnist' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
# ...

# %% [markdown]
# ## Model Training

# %%
# !python train.py -c config.json
# Out:
# AlexNet(
#   (layers): Sequential(
#     (0): Conv2d(3, 96, kernel_size=(11, 11), stride=(4, 4))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(96, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(256, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU()
#     (10): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU()
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.5, inplace=False)
# ...

# %%
# !ls
# Out:
# base	     data_loader  logger  parse_config.py   test.py  train.py
# config.json  exe.ipynb	  model   requirements.txt  trainer  utils

# %% [markdown]
# ____
# ## github

# %%
# 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
# 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
from os.path import join  

# path to your project on Google Drive
# MY_GOOGLE_DRIVE_PATH = '/MyDrive/ColabNotebooks/week2/project/alexnet' 
# replace with your Github username 
GIT_USERNAME = "nebulajo" 
# definitely replace with your
GIT_TOKEN = "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"  
# Replace with your github repository in this case we want 
# to clone deep-learning-v2-pytorch repository
GIT_REPOSITORY = "alexnet_implementation" 

# PROJECT_PATH = join(ROOT, MY_GOOGLE_DRIVE_PATH)
PROJECT_PATH = 'content/drive/MyDrive/ColabNotebooks/week2/project/alexnet'

# It's good to print out the value if you are not sure 
print("PROJECT_PATH: ", PROJECT_PATH)   

# In case we haven't created the folder already; we will create a folder in the project path 
# !mkdir "{PROJECT_PATH}"    

#GIT_PATH = "https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git" this return 400 Bad Request for me
GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# PROJECT_PATH:  content/drive/MyDrive/ColabNotebooks/week2/project/alexnet
# mkdir: cannot create directory ‘content/drive/MyDrive/ColabNotebooks/week2/project/alexnet’: No such file or directory
# GIT_PATH:  https://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@github.com/nebulajo/alexnet_implementation.git

# %%
join(ROOT, MY_GOOGLE_DRIVE_PATH)
# Out:
# '/MyDrive/ColabNotebooks/week2/project/alexnet'

# %%
# %cd "{PROJECT_PATH}"    # Change directory to the location defined in project_path
# !git clone "{GIT_PATH}" . # clone the github repository
# Out:
# Cloning into '.'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 44 (delta 8), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (44/44), 2.09 MiB | 3.44 MiB/s, done.

# %%
# %cd alexnet2/
# Out:
# /content/drive/MyDrive/ColabNotebooks/week2/project/alexnet2

# %%
# Out:
# drive  sample_data

# %%
# !git config
# Out:
# usage: git config [<options>]
#
# Config file location
#     --global              use global config file
#     --system              use system config file
#     --local               use repository config file
#     --worktree            use per-worktree config file
#     -f, --file <file>     use given config file
#     --blob <blob-id>      read config from given blob object
#
# Action
#     --get                 get value: name [value-regex]
#     --get-all             get all values: key [value-regex]
#     --get-regexp          get values for regexp: name-regex [value-regex]
#     --get-urlmatch        get value specific for the URL: section[.var] URL
#     --replace-all         replace all matching variables: name value [value_regex]
#     --add                 add a new variable: name value
#     --unset               remove a variable: name [value-regex]
#     --unset-all           remove all matches: name [value-regex]
# ...

# %%
# !git pull
# Out:
# Already up to date.
