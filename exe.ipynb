# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/week2/project/pytorch-template/
# !ls
# Out:
# /content/drive/MyDrive/ColabNotebooks/week2/project/pytorch-template
# base	     exe.ipynb	model		 README.md	   trainer
# config.json  LICENSE	new_project.py	 requirements.txt  train.py
# data_loader  logger	parse_config.py  test.py	   utils
